# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
property = pd.read_csv("data_kaggle.csv")
new = property.dropna()

# %%
new.loc[(new["Price"]=="RM 2,500")&(new["Location"]=="KLCC, Kuala Lumpur")]
# Out:
#                  Location     Price Rooms  Bathrooms  Car Parks Property Type  \
# 28255  KLCC, Kuala Lumpur  RM 2,500   1+1        2.0        1.0   Condominium
#
#                          Size       Furnishing
# 28255  Built-up : 850 sq. ft.  Fully Furnished

# %%
a = new.loc[new["Location"]=="KLCC, Kuala Lumpur"]
b = list(a.Price)

# %%
abg = 0
c = []
for e in b:
    c.append(b[abg].split())
    abg+=1

# %%
newlist = []
def functtt():
    a = 0
    for e in c:
        d = c[a][1]
        a+=1
        newlist.append(d)
        
functtt()

# %%
newnew = []
for e in newlist:
    newnew.append(e.replace(",",""))

# %%
for e in newnew:
    int(e)

# %%
max_value = len([int(i) for i in newnew])
max_value
# Out:
# 3177

# %%
a.loc[a["Property Type"]=="Serviced Residence"]
# Out:
#                  Location         Price Rooms  Bathrooms  Car Parks  \
# 0      KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0        2.0
# 35     KLCC, Kuala Lumpur  RM 2,400,000     2        2.0        1.0
# 43     KLCC, Kuala Lumpur  RM 2,300,000     1        2.0        1.0
# 81     KLCC, Kuala Lumpur  RM 1,799,000     1        1.0        1.0
# 87     KLCC, Kuala Lumpur  RM 2,300,000     1        1.0        2.0
# ...                   ...           ...   ...        ...        ...
# 53063  KLCC, Kuala Lumpur  RM 3,380,000   3+1        3.0        2.0
# 53072  KLCC, Kuala Lumpur  RM 1,100,000   1+1        1.0        1.0
# 53385  KLCC, Kuala Lumpur  RM 1,600,000     3        2.0        1.0
# 53431  KLCC, Kuala Lumpur  RM 1,250,000     3        3.0        1.0
# 53432  KLCC, Kuala Lumpur  RM 1,250,000     3        2.0        1.0
#
#             Property Type                      Size        Furnishing
# 0      Serviced Residence  Built-up : 1,335 sq. ft.   Fully Furnished
# ...

# %%
pricyy  = [29000000,16000000,2400000,1200000,2500]

placy = ["Bungalow(with more rooms)(29mil)","Bungalow(16mil)","Serviced Residence(2.4mil)","Condominium(1000+sq.ft)(1.6mil)","Condominium(800<sq.ft)(2.5k)"]

# %%
plt.figure(figsize=(15,4),dpi=600)
plt.bar(placy,pricyy,label="Properties in KLCC")
# plt.xlabel("Properties",fontsize=16.8,color="r")
plt.ylabel("Price in RM",fontsize=20,color="b")
plt.style.use("seaborn")
plt.legend()
plt.title("Most Expensive to Cheapest property in KLCC",fontsize=28,color="g")
plt.savefig("barccc1.png",dpi=600)
plt.show()

# %%
a.Bathrooms.plot()

# %%
aha = []
for e in newnew:
    aha.append(int(e))
aha.sort()

# %%
dkd=1
longg=[]
for e in aha:
    if dkd<(len(aha)-1):
        dkd+=1
        if e!=aha[dkd]:
            aha.pop(aha)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-425-f580ce038f7d> in <module>
#       5         dkd+=1
#       6         if e!=aha[dkd]:
# ----> 7             aha.pop(aha)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
aha= set([i for i in aha if aha.count(i)>1])

# %%
# Out:
# {3300,
#  5000,
#  5500,
#  7500,
#  7800,
#  7900,
#  8000,
#  9000,
#  420000,
#  498000,
#  520000,
#  550000,
#  570000,
#  575000,
#  635000,
#  650000,
#  660000,
#  680000,
#  689000,
#  690000,
#  700000,
#  720000,
#  750000,
#  756000,
#  780000,
#  798000,
#  799000,
#  800000,
#  810000,
#  815000,
#  820000,
#  825000,
#  830000,
#  835000,
#  840000,
#  845000,
#  850000,
#  852000,
#  860000,
#  870000,
#  875000,
#  880000,
#  890000,
#  898000,
#  899000,
#  900000,
#  915000,
#  918000,
#  920000,
#  928000,
#  930000,
#  940000,
#  945000,
#  950000,
#  970000,
#  980000,
#  985000,
#  990000,
#  993000,
#  999000,
#  1000000,
#  1020000,
#  1050000,
#  1062800,
#  1070000,
#  1080000,
#  1085000,
#  1085700,
#  1090000,
#  1098000,
#  1100000,
#  1110000,
#  1111800,
#  1120000,
#  1130000,
#  1143000,
#  1145000,
#  1150000,
#  1158000,
#  1160000,
#  1166100,
#  1170000,
#  1180000,
#  1190000,
#  1194000,
#  1198000,
#  1198800,
#  1200000,
#  1220000,
# ...
